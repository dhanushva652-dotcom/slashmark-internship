# %% [markdown]
# # Sentiment Analysis Task 1
# This notebook follows the internship requirements: preprocessing, TF-IDF, classical ML, and evaluation.

# %%
from src.train import train_and_select_best_model
metrics = train_and_select_best_model()
metrics['accuracy'], metrics['f1_weighted']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.train import train_and_select_best_model
#       2 metrics = train_and_select_best_model()
#       3 metrics['accuracy'], metrics['f1_weighted']
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.predict import predict_sentiment
predict_sentiment('The food was amazing and the staff were friendly!')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.predict import predict_sentiment
#       2 predict_sentiment('The food was amazing and the staff were friendly!')
#
# ModuleNotFoundError: No module named 'src'
